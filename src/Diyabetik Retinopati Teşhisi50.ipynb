# %%
import pandas as pd
import numpy as np

# %%
path = 'C:\\Users\\Hasan\\Desktop\\'

# %%
df = pd.read_csv(path + 'train.csv', sep = ',')

# %%
df.head(10)
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0
# 5  0083ee8054ee          4
# 6  0097f532ac9f          0
# 7  00a8624548a9          2
# 8  00b74780d31d          2
# 9  00cb6555d108          1

# %%
df['diagnosis'].hist()
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    1805
# 2     999
# 1     370
# 4     295
# 3     193
# Name: count, dtype: int64

# %% [markdown]
# Retinopati görüntülerini aktarmak için, **os.listdir()** kullanarak *''train_img''* klasöründe bulunan dosyaların isimlerini *''files''* ismine atadım.
# * '000c1434d8d7.png'
# * '001639a390f0.png'
# * '0024cdab0c1e.png'
# *  ...

# %%
import os
files = os.listdir(path + 'train_img')
# files

# %%
len(files)
# Out:
# 3662

# %%
import cv2

# %% [markdown]
# OpenCV'nin [görüntü okuma modülü](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html)nü kullanarak **files**'ın içindeki görüntü isimleri üzerinden bir for döngüsü döndürerek görüntüleri okuduk. Ardından bunları (400,400,3) boyutunda yeniden şekillendirdik. OpenCV görüntüleri BGR şeklinde okuduğu için bunları RGB renk koduna çevirdik. Ardından döngüde dönen her görüntüyü *img_list* ismindeki listeye ekledik.

# %%
img_list = []

for i in files[0:20]:
    image = cv2.imread(path + 'train_img\\'+i)
    image = cv2.resize(image,(400,400))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    img_list.append(image)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img_list[0])

# %%
plt.imshow(img_list[4])

# %%
kopya = img_list[4].copy()

# %% [markdown]
# #### Threshold uygulayabilmek için görüntümüzü siyah-beyaz renklere çevirdik.

# %%
kopya = cv2.cvtColor(kopya, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(kopya, cmap='gray')

# %% [markdown]
# #### Görüntü siyah beyaz olduğu için RGB kanallarını kaybederek (400,400) boyutuna indirgendi.

# %%
kopya.shape
# Out:
# (400, 400)

# %% [markdown]
# #### Threshold'un daha başarılı uygulanabilmesi için bir miktar Blur uyguluyoruz.

# %%
blur = cv2.GaussianBlur(kopya,(5,5),0)

# %%
plt.imshow(blur,cmap='gray')

# %% [markdown]
# Burada görüntü üzerinde  **10 değerinin üzerinde bulduğu tüm değerleri 255 değerine eşitledik**

# %%
thresh = cv2.threshold(blur,10,255, cv2.THRESH_BINARY)[1]

# %%
plt.imshow(thresh, cmap='gray')

# %% [markdown]
# Kırpma işlemini yapmak için elimizdeki yeni görüntünün **kenar koordinatlarını(kontur)** buluyoruz.

# %%
kontur = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# kontur

# %%
 kontur = kontur[0][0]

# %%
kontur.shape
# Out:
# (452, 1, 2)

# %%
kontur = kontur[:,0,:]

# %%
kontur.shape
# Out:
# (452, 2)

# %%
# kontur

# %%
kontur[:,0].argmax()
# Out:
# 335

# %%
kontur[335]
# Out:
# array([332, 218], dtype=int32)

# %%
kontur[:,0].argmin()
# Out:
# 111

# %%
kontur[111]
# Out:
# array([ 63, 185], dtype=int32)

# %%
sol = tuple(kontur[kontur[:,0].argmin()])
sağ = tuple(kontur[kontur[:,0].argmax()])
üst = tuple(kontur[kontur[:,1].argmin()])
alt = tuple(kontur[kontur[:,1].argmax()])

# %% [markdown]
# Görüntümüzün **4 uç noktasına ait koordinatları**nı elde ettik.

# %%
sol, sağ, üst, alt
# Out:
# ((63, 185), (332, 218), (188, 21), (194, 380))

# %%
x1 = sol[0]
y1 = üst[1]
x2 = sağ[0]
y2 = alt[1]

# %%
x1, y1, x2, y2
# Out:
# (63, 21, 332, 380)

# %%
orijinal = img_list[4].copy()

# %%
plt.imshow(orijinal)

# %%
crop_ilk = orijinal[y1:y2 , x1:x2]

# %%
plt.imshow(crop_ilk)

# %%
crop_ilk.shape
# Out:
# (359, 269, 3)

# %% [markdown]
# Kıprma işlemini yaptıktan sonra görüntü boyut kayması yaşadığı için tekrardan (400,400) boyutuna eşitliyoruz.

# %%
crop_ilk = cv2.resize(crop_ilk,(400,400))

# %%
plt.imshow(crop_ilk)

# %% [markdown]
# Kenarlardaki veriler gereksiz olduğu için bir eşik belirleyip, bir miktar daha görüntüleri kırpıyoruz.

# %%
x = int(x2-x1)*4//100
y = int(y2-y1)*5//100

# %%
x,y
# Out:
# (10, 17)

# %%
crop_son = orijinal[y1+y : y2-y , x1+x : x2-x]

# %%
plt.imshow(crop_son)

# %%
crop_son = cv2.resize(crop_son,(400,400))

# %%
plt.imshow(crop_son)

# %% [markdown]
# ## CLAHE - Kontrast Limitli Adaptif Histogram Eşitleme

# %% [markdown]
# CLAHE uygulamak için renk kanalını RGB'den LAB'a çeviriyoruz.

# %%
lab = cv2.cvtColor(crop_son, cv2.COLOR_RGB2LAB)

# %%
lab.shape
# Out:
# (400, 400, 3)

# %%
l,a,b = cv2.split(lab)

# %% [markdown]
# LAB'daki ''l'' görüntünün siyah-beyaz parlaklık değerini içeriyor. CLAHE işlemini sadece bu katmana uygulayacağız.

# %%
plt.imshow(l, cmap='gray')

# %%
l.shape
# Out:
# (400, 400)

# %%
düz = l.flatten()

# %%
düz.shape
# Out:
# (160000,)

# %%
plt.hist(düz,25,[0,256], color = 'r')
plt.show()

# %%
clahe = cv2.createCLAHE(clipLimit=7.0,tileGridSize=((8,8)))
cl = clahe.apply(l)

# %%
plt.hist(cl.flatten(),25,[0,256], color = 'r')
plt.show()

# %% [markdown]
# ## CLAHE uygulanmış hali

# %%
plt.imshow(cl)

# %% [markdown]
# ## CLAHE uygulanmamış hali

# %%
plt.imshow(l)

# %% [markdown]
# CLAHE işlemi uyguladığımız katmanı, diğer katmanlarla birleştirip tekrardan görüntümüzü RGB yapıyoruz.

# %%
limg = cv2.merge((cl,a,b))

# %%
son = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)

# %%
plt.imshow(son)

# %%
plt.imshow(crop_son)

# %% [markdown]
# ## Median Blur

# %%
med_son = cv2.medianBlur(son, 3)

# %%
plt.imshow(med_son)

# %%
arka_plan = cv2.medianBlur(son, 37)

# %%
plt.imshow(arka_plan)

# %%
maske = cv2.addWeighted(med_son,1,arka_plan,-1,255)
plt.imshow(maske)

# %%
son_img = cv2.bitwise_and(maske,med_son)

# %%
plt.imshow(son_img)

# %%
plt.imshow(med_son)

# %% [markdown]
# #### Yaptığımız tüm işlemleri tek bir for döngüsünde toplayıp, elimizdeki bütün görüntüleri bu döngüyle img_list ismindeki listeye kaydediyoruz.

# %%
img_list = []

from tqdm.notebook import tqdm

for i in tqdm(files):
    image = cv2.imread(path + 'train_img\\'+i)
    image = cv2.resize(image,(400,400))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    kopya = image.copy()
    kopya = cv2.cvtColor(kopya, cv2.COLOR_RGB2GRAY)
    blur = cv2.GaussianBlur(kopya,(5,5),0)
    thresh = cv2.threshold(blur,10,255, cv2.THRESH_BINARY)[1]
    kontur = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    kontur = kontur[0][0]
    kontur = kontur[:,0,:]
    x1 = tuple(kontur[kontur[:,0].argmin()])[0]
    y1 = tuple(kontur[kontur[:,1].argmin()])[1]
    x2 = tuple(kontur[kontur[:,0].argmax()])[0]
    y2 = tuple(kontur[kontur[:,1].argmax()])[1]
    x = int(x2-x1)*4//50
    y = int(y2-y1)*5//50
    kopya2 = image.copy()
    if x2-x1 >100 and y2-y1> 100:
        kopya2 = kopya2[y1+y : y2-y , x1+x : x2-x]
        kopya2 = cv2.resize(kopya2,(400,400))
    lab = cv2.cvtColor(kopya2, cv2.COLOR_RGB2LAB)
    l,a,b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=5.0,tileGridSize=((8,8)))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    son = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    med_son = cv2.medianBlur(son, 3)
    arka_plan = cv2.medianBlur(son, 37)
    maske = cv2.addWeighted(med_son,1,arka_plan,-1,255)
    son_img = cv2.bitwise_and(maske,med_son)
    img_list.append(son_img)
# Out:
#   0%|          | 0/3662 [00:00<?, ?it/s]

# %%
plt.imshow(img_list[6])

# %%
plt.imshow(img_list[6])

# %%
fig = plt.figure(figsize=(20,12))

for i in range(12):
    img = img_list[i]
    fig.add_subplot(3,4,i+1)
    plt.imshow(img)

plt.tight_layout()

# %%
# df['diagnosis']

# %% [markdown]
# ### One Hot Encoding

# %%
y_train = pd.get_dummies(df['diagnosis']).values

# %%
# y_train

# %%
df['diagnosis'][1]
# Out:
# 4

# %%
y_train[1]
# Out:
# array([False, False, False, False,  True])

# %%
y_train_son = np.ones(y_train.shape, dtype='uint8')

# %%
# y_train_son

# %%
y_train_son[:,4] = y_train[:,4]

# %%
# y_train_son

# %%
import numpy as np

# %%
np.logical_or(0,0)
# Out:
# False

# %%
np.logical_or(1,0)
# Out:
# True

# %%
np.logical_or(0,1)
# Out:
# True

# %%
np.logical_or(1,1)
# Out:
# True

# %%
np.logical_and(0,1)
# Out:
# False

# %%
np.logical_and(1,1)
# Out:
# True

# %%
for i in range(3,-1,-1):
    y_train_son[:,i] = np.logical_or(y_train[:,i], y_train_son[:,i+1])

# %%
# y_train_son

# %%
# y_train

# %%
x_train = np.array(img_list)

# %%
x_train.shape
# Out:
# (3662, 400, 400, 3)

# %%
y_train_son.shape
# Out:
# (3662, 5)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val , y_train, y_val = train_test_split(x_train,
                                                   y_train_son,
                                                   test_size=0.3,
                                                   random_state=2019,
                                                   shuffle=True)

# %%
x_train.shape, x_val.shape , y_train.shape, y_val.shape
# Out:
# ((2563, 400, 400, 3), (1099, 400, 400, 3), (2563, 5), (1099, 5))

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True)
data_generator = datagen.flow(x_train,y_train,batch_size=2,seed=2020)

# %%
from tensorflow.keras.applications import EfficientNetB5

# %%
örnek_model = EfficientNetB5()

# %%
#örnek_model.summary()

# %%
örnek_model2 = EfficientNetB5(include_top=False)
#örnek_model2.summary()

# %%
from keras.models import Sequential
from keras import layers

model = Sequential()
model.add(EfficientNetB5(weights='imagenet',include_top=False, input_shape=(400,400,3)))
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(5, activation='sigmoid'))

# %%
from keras.optimizers import Adam
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.00005), metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau

lr = ReduceLROnPlateau(monitor = 'val_loss',
                      patience = 3,
                      verbose = 1,
                      mode='auto',
                      factor=0.25,
                      min_lr=0.000001)

# %%
history = model.fit(data_generator,
                             steps_per_epoch = 1000,
                             epochs = 50,
                             validation_data = (x_val,y_val),
                             callbacks = [lr])
# Out:
# Epoch 1/50
# C:\Users\Hasan\anaconda3\envs\tensorflow\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3054s 3s/step - accuracy: 0.9304 - loss: 0.3916 - val_accuracy: 0.9181 - val_loss: 0.1838 - learning_rate: 5.0000e-05
# Epoch 2/50
#  282/1000 ━━━━━━━━━━━━━━━━━━━━ 32:16 3s/step - accuracy: 0.9327 - loss: 0.1894
# C:\Users\Hasan\anaconda3\envs\tensorflow\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 975s 973ms/step - accuracy: 0.9390 - loss: 0.1888 - val_accuracy: 0.9700 - val_loss: 0.1671 - learning_rate: 5.0000e-05
# Epoch 3/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2924s 3s/step - accuracy: 0.9073 - loss: 0.1858 - val_accuracy: 0.9900 - val_loss: 0.1607 - learning_rate: 5.0000e-05
# Epoch 4/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 969s 967ms/step - accuracy: 0.9017 - loss: 0.1318 - val_accuracy: 0.9518 - val_loss: 0.1407 - learning_rate: 5.0000e-05
# Epoch 5/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2891s 3s/step - accuracy: 0.8885 - loss: 0.1554 - val_accuracy: 0.9472 - val_loss: 0.1381 - learning_rate: 5.0000e-05
# Epoch 6/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 964s 962ms/step - accuracy: 0.9163 - loss: 0.1337 - val_accuracy: 0.9909 - val_loss: 0.1319 - learning_rate: 5.0000e-05
# Epoch 7/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2897s 3s/step - accuracy: 0.9163 - loss: 0.1337 - val_accuracy: 0.9945 - val_loss: 0.1473 - learning_rate: 5.0000e-05
# Epoch 8/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 966s 964ms/step - accuracy: 0.9016 - loss: 0.1071 - val_accuracy: 0.9800 - val_loss: 0.1415 - learning_rate: 5.0000e-05
# Epoch 9/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9134 - loss: 0.1027
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2885s 3s/step - accuracy: 0.9134 - loss: 0.1027 - val_accuracy: 0.9718 - val_loss: 0.1672 - learning_rate: 5.0000e-05
# Epoch 10/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 964s 962ms/step - accuracy: 0.8875 - loss: 0.0850 - val_accuracy: 0.9672 - val_loss: 0.1378 - learning_rate: 1.2500e-05
# Epoch 11/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2885s 3s/step - accuracy: 0.8925 - loss: 0.0796 - val_accuracy: 0.9518 - val_loss: 0.1529 - learning_rate: 1.2500e-05
# Epoch 12/50
#  282/1000 ━━━━━━━━━━━━━━━━━━━━ 32:04 3s/step - accuracy: 0.8775 - loss: 0.0821
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 969s 968ms/step - accuracy: 0.8662 - loss: 0.0838 - val_accuracy: 0.9208 - val_loss: 0.1397 - learning_rate: 1.2500e-05
# Epoch 13/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2882s 3s/step - accuracy: 0.8731 - loss: 0.0754 - val_accuracy: 0.9418 - val_loss: 0.1476 - learning_rate: 3.1250e-06
# Epoch 14/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1345s 1s/step - accuracy: 0.8878 - loss: 0.0648 - val_accuracy: 0.9454 - val_loss: 0.1470 - learning_rate: 3.1250e-06
# Epoch 15/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8894 - loss: 0.0672
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2901s 3s/step - accuracy: 0.8894 - loss: 0.0672 - val_accuracy: 0.9299 - val_loss: 0.1465 - learning_rate: 3.1250e-06
# Epoch 16/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 977s 976ms/step - accuracy: 0.8845 - loss: 0.0652 - val_accuracy: 0.9308 - val_loss: 0.1466 - learning_rate: 1.0000e-06
# Epoch 17/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2894s 3s/step - accuracy: 0.8855 - loss: 0.0695 - val_accuracy: 0.9436 - val_loss: 0.1534 - learning_rate: 1.0000e-06
# Epoch 18/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 968s 966ms/step - accuracy: 0.8843 - loss: 0.0693 - val_accuracy: 0.9399 - val_loss: 0.1495 - learning_rate: 1.0000e-06
# Epoch 19/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13830s 14s/step - accuracy: 0.8987 - loss: 0.0680 - val_accuracy: 0.9454 - val_loss: 0.1523 - learning_rate: 1.0000e-06
# Epoch 20/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 976s 974ms/step - accuracy: 0.8751 - loss: 0.0643 - val_accuracy: 0.9308 - val_loss: 0.1485 - learning_rate: 1.0000e-06
# Epoch 21/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2891s 3s/step - accuracy: 0.9013 - loss: 0.0618 - val_accuracy: 0.9345 - val_loss: 0.1524 - learning_rate: 1.0000e-06
# Epoch 22/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 965s 963ms/step - accuracy: 0.9026 - loss: 0.0612 - val_accuracy: 0.9409 - val_loss: 0.1520 - learning_rate: 1.0000e-06
# Epoch 23/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2907s 3s/step - accuracy: 0.8854 - loss: 0.0630 - val_accuracy: 0.9409 - val_loss: 0.1553 - learning_rate: 1.0000e-06
# Epoch 24/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 970s 968ms/step - accuracy: 0.8923 - loss: 0.0753 - val_accuracy: 0.9354 - val_loss: 0.1545 - learning_rate: 1.0000e-06
# Epoch 25/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2958s 3s/step - accuracy: 0.8860 - loss: 0.0626 - val_accuracy: 0.9399 - val_loss: 0.1571 - learning_rate: 1.0000e-06
# Epoch 26/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 993s 991ms/step - accuracy: 0.9071 - loss: 0.0543 - val_accuracy: 0.9345 - val_loss: 0.1554 - learning_rate: 1.0000e-06
# Epoch 27/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2920s 3s/step - accuracy: 0.8964 - loss: 0.0617 - val_accuracy: 0.9381 - val_loss: 0.1544 - learning_rate: 1.0000e-06
# Epoch 28/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 974s 972ms/step - accuracy: 0.8847 - loss: 0.0605 - val_accuracy: 0.9409 - val_loss: 0.1566 - learning_rate: 1.0000e-06
# Epoch 29/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2913s 3s/step - accuracy: 0.8957 - loss: 0.0533 - val_accuracy: 0.9363 - val_loss: 0.1547 - learning_rate: 1.0000e-06
# Epoch 30/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 973s 972ms/step - accuracy: 0.9004 - loss: 0.0559 - val_accuracy: 0.9372 - val_loss: 0.1568 - learning_rate: 1.0000e-06
# Epoch 31/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2902s 3s/step - accuracy: 0.8859 - loss: 0.0679 - val_accuracy: 0.9308 - val_loss: 0.1591 - learning_rate: 1.0000e-06
# Epoch 32/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 968s 967ms/step - accuracy: 0.8940 - loss: 0.0518 - val_accuracy: 0.9390 - val_loss: 0.1604 - learning_rate: 1.0000e-06
# Epoch 33/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2902s 3s/step - accuracy: 0.9008 - loss: 0.0582 - val_accuracy: 0.9390 - val_loss: 0.1606 - learning_rate: 1.0000e-06
# Epoch 34/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 986s 985ms/step - accuracy: 0.8868 - loss: 0.0629 - val_accuracy: 0.9409 - val_loss: 0.1615 - learning_rate: 1.0000e-06
# Epoch 35/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2919s 3s/step - accuracy: 0.8915 - loss: 0.0619 - val_accuracy: 0.9327 - val_loss: 0.1569 - learning_rate: 1.0000e-06
# Epoch 36/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 980s 978ms/step - accuracy: 0.8776 - loss: 0.0646 - val_accuracy: 0.9354 - val_loss: 0.1587 - learning_rate: 1.0000e-06
# Epoch 37/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2933s 3s/step - accuracy: 0.8807 - loss: 0.0572 - val_accuracy: 0.9308 - val_loss: 0.1601 - learning_rate: 1.0000e-06
# Epoch 38/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 986s 984ms/step - accuracy: 0.8840 - loss: 0.0586 - val_accuracy: 0.9363 - val_loss: 0.1631 - learning_rate: 1.0000e-06
# Epoch 39/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2911s 3s/step - accuracy: 0.8710 - loss: 0.0597 - val_accuracy: 0.9354 - val_loss: 0.1644 - learning_rate: 1.0000e-06
# Epoch 40/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 988s 986ms/step - accuracy: 0.8921 - loss: 0.0523 - val_accuracy: 0.9327 - val_loss: 0.1603 - learning_rate: 1.0000e-06
# Epoch 41/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2983s 3s/step - accuracy: 0.8740 - loss: 0.0663 - val_accuracy: 0.9336 - val_loss: 0.1641 - learning_rate: 1.0000e-06
# Epoch 42/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1007s 1s/step - accuracy: 0.9033 - loss: 0.0580 - val_accuracy: 0.9381 - val_loss: 0.1664 - learning_rate: 1.0000e-06
# Epoch 43/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2944s 3s/step - accuracy: 0.8908 - loss: 0.0570 - val_accuracy: 0.9363 - val_loss: 0.1661 - learning_rate: 1.0000e-06
# Epoch 44/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 988s 986ms/step - accuracy: 0.8787 - loss: 0.0525 - val_accuracy: 0.9299 - val_loss: 0.1629 - learning_rate: 1.0000e-06
# Epoch 45/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2920s 3s/step - accuracy: 0.8895 - loss: 0.0532 - val_accuracy: 0.9308 - val_loss: 0.1611 - learning_rate: 1.0000e-06
# Epoch 46/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 982s 980ms/step - accuracy: 0.8724 - loss: 0.0528 - val_accuracy: 0.9290 - val_loss: 0.1654 - learning_rate: 1.0000e-06
# Epoch 47/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2933s 3s/step - accuracy: 0.8743 - loss: 0.0612 - val_accuracy: 0.9263 - val_loss: 0.1620 - learning_rate: 1.0000e-06
# Epoch 48/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 993s 991ms/step - accuracy: 0.8836 - loss: 0.0502 - val_accuracy: 0.9354 - val_loss: 0.1644 - learning_rate: 1.0000e-06
# Epoch 49/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2943s 3s/step - accuracy: 0.8895 - loss: 0.0548 - val_accuracy: 0.9217 - val_loss: 0.1672 - learning_rate: 1.0000e-06
# Epoch 50/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 988s 987ms/step - accuracy: 0.8746 - loss: 0.0491 - val_accuracy: 0.9336 - val_loss: 0.1671 - learning_rate: 1.0000e-06

# %%
# History'den eğitim ve doğrulama metriklerini alma
history_dict = history.history

# %%
# Eğitim ve doğrulama kaybı (loss)
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

# %%
# Eğitim ve doğrulama doğruluğu (accuracy)
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

# %%
epochs = range(1, len(loss_values) + 1)

# %%
# Doğruluk değerlerini 0-100 arasında bir ölçeğe çekiyoruz
acc_values_scaled = [x * 100 for x in acc_values]
val_acc_values_scaled = [x * 100 for x in val_acc_values]

# %%
# Kayıp (Loss) Grafiği
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, loss_values, 'r', label='Training Loss')  # 'bo' mavi noktalar
plt.plot(epochs, val_loss_values, 'b', label='Validation Loss')  # 'b' mavi çizgi
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Doğruluk (Accuracy) Grafiği
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(epochs, acc_values, 'r', label='Training Accuracy')  # 'ro' kırmızı noktalar
plt.plot(epochs, val_acc_values, 'b', label='Validation Accuracy')  # 'r' kırmızı çizgi
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Doğrulama verisini test (%15) ve doğrulama (%15) olarak ayırma
x_val, x_test, y_val, y_test = train_test_split(
    x_val, y_val, 
    test_size=0.5,  # %30'un yarısı (%15)
    random_state=2019, 
    shuffle=True
)

# Test veri seti üzerinde tahmin yapma
y_pred = model.predict(x_test)  # Test veri setinden tahminler
y_pred_classes = np.argmax(y_pred, axis=1)  # Tahmin edilen sınıflar (en yüksek olasılık)
y_true = np.argmax(y_test, axis=1)  # Gerçek sınıflar (one-hot encoded ise)

# Karmaşıklık matrisi oluşturma
cm = confusion_matrix(y_true, y_pred_classes)

# Sınıf etiketlerini tanımlama
class_names = ['Normal', 'Mild', 'Moderate', 'Severe', 'Proliferative']  # Sınıflarınızı buraya yazın

# Karmaşıklık matrisi grafiği
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap='Blues', values_format='d')  # Renk haritası ve sayı formatı
plt.title("Confusion Matrix")
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 145s 7s/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 27
#      25 # Karmaşıklık matrisi grafiği
#      26 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
# ---> 27 disp.plot(cmap='Blues', values_format='d')  # Renk haritası ve sayı formatı
#      28 plt.title("Confusion Matrix")
#      29 plt.show()
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:181, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179 if colorbar:
#     180     fig.colorbar(self.im_, ax=ax)
# --> 181 ax.set(
#     182     xticks=np.arange(n_classes),
#     183     yticks=np.arange(n_classes),
#     184     xticklabels=display_labels,
#     185     yticklabels=display_labels,
#     186     ylabel="True label",
#     187     xlabel="Predicted label",
#     188 )
#     190 ax.set_ylim((n_classes - 0.5, -0.5))
#     191 plt.setp(ax.get_xticklabels(), rotation=xticks_rotation)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py:1224, in Artist.set(self, **kwargs)
#    1220 def set(self, **kwargs):
#    1221     # docstring and signature are auto-generated via
#    1222     # Artist._update_set_signature_and_docstring() at the end of the
#    1223     # module.
# -> 1224     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py:1192, in Artist._update_props(self, props, errfmt)
#    1189             if not callable(func):
#    1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
# -> 1192             ret.append(func(v))
#    1193 if ret:
#    1194     self.pchanged()
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axis.py:2071, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2067 elif isinstance(locator, mticker.FixedLocator):
#    2068     # Passing [] as a list of labels is often used as a way to
#    2069     # remove all tick labels, so only error for > 0 labels
#    2070     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2071         raise ValueError(
#    2072             "The number of FixedLocator locations"
#    2073             f" ({len(locator.locs)}), usually from a call to"
#    2074             " set_ticks, does not match"
#    2075             f" the number of labels ({len(labels)}).")
#    2076     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2077     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of labels (5).
